# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from numpy.random import rand
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
def error_rate(features, target, x, opts):
    # parameters
    k     = opts['k']
    cv    = opts['cv']

    kf = KFold(n_splits=cv, shuffle=True, random_state=2)

    total_error = 0

    for train_index, test_index in kf.split(features):
      X_train, X_test = features[train_index], features[test_index]
      y_train, y_test = target[train_index], target[test_index]

      # Number of instances
      num_train = np.size(X_train, 0)
      num_test  = np.size(X_test, 0)
      
      # Define selected features
      xtrain = X_train[:, x==1]
      ytrain = y_train.reshape(num_train)
      xtest  = X_test[:, x==1]
      ytest  = y_test.reshape(num_test)

      # Training
      knn = KNeighborsClassifier(n_neighbors=k)
      knn.fit(xtrain, ytrain)

      # Prediction
      ypred = knn.predict(xtest)
      acc   = np.sum(ytest == ypred) / num_test
      error = 1 - acc

      total_error = total_error + error
      
    return total_error/cv

# %%
def Fun(features, target, x, opts):
    # Parameters
    alpha    = 0.99
    beta     = 1 - alpha
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if num_feat == 0:
        cost  = 1
    else:
        # Get error rate
        error = error_rate(features, target, x, opts)
        # Objective function
        cost  = alpha * error + beta * (num_feat / max_feat)
        
    return cost

# %%
def init_position(lb, ub, N, dim):
    X = np.zeros([N, dim], dtype='float')
    R = rand()
    u = 1 + R
    for d in range(dim):
        X[0,d] = lb[0,d] + (ub[0,d] - lb[0,d]) * rand()
    for i in range(1, N):
        for d in range(dim):
            if X[i-1,d] <= 0.5:
                X[i,d] = u * X[i-1,d]
            else:
                X[i,d] = u * (1 - X[i-1,d])
    
    return X

# %%
def binary_conversion(X, thres, N, dim):
    Xbin = np.zeros([N, dim], dtype='int')
    for i in range(N):
        for d in range(dim):
            xi = 1/(1 + np.exp(-X[i,d]))
            if xi > rand():
            # if X[i,d] > 0.5:
                Xbin[i,d] = 0
            else:
                Xbin[i,d] = 1
    
    return Xbin

# %%
def boundary(x, lb, ub):
    if x < lb:
        x = lb
    if x > ub:
        x = ub
    
    return x

# %%
def woaPso(features, target, opts):
    # Parameters
    ub    = 1
    lb    = 0
    thres = rand()
    b     = 1       # constant
    c1    = 2
    c2    = 2
    
    N        = opts['N']
    max_iter = opts['T']
    if 'b' in opts:
        b    = opts['b']
    
    # Dimension
    dim = np.size(features, 1)
    if np.size(lb) == 1:
        ub = ub * np.ones([1, dim], dtype='float')
        lb = lb * np.ones([1, dim], dtype='float')
        
    # Initialize position 
    X    = init_position(lb, ub, N, dim)
    
    # Binary conversion
    Xbin = binary_conversion(X, thres, N, dim)
    
    # Fitness at first iteration
    fit  = np.zeros([N, 1], dtype='float')
    Xgb  = np.zeros([1, dim], dtype='float')
    fitG = float('inf')
    
    for i in range(N):
        fit[i,0] = Fun(features, target, Xbin[i,:], opts)
        if fit[i,0] < fitG:
            Xgb[0,:] = X[i,:]
            fitG     = fit[i,0]
        
    # Pre
    curve = np.zeros([1, max_iter], dtype='float') 
    t     = 0
    
    curve[0,t] = fitG.copy()
    print("Generation:", t + 1)
    print("Best (WOA):", curve[0,t])
    t += 1

    while t < max_iter:
        # Define a, linearly decreases from 2 to 0 
        a = 2 - t * (2 / max_iter)
        
        for i in range(N):
            # Parameter A (2.3)
            A = 2 * a * rand() - a
            # Paramater C (2.4)
            C = 2 * rand()
            # Parameter p, random number in [0,1]
            p = rand()
            # Parameter l, random number in [-1,1]
            l = -1 + 2 * rand() 
            # Random parameters
            r1 = rand()
            r2 = rand() 
            # Whale position update (2.6)
            if p  < 0.5:
                # {1} Encircling prey
                if abs(A) < 1:
                    for d in range(dim):
                        # Compute D (2.1)
                        Dx     = abs(C * Xgb[0,d] - X[i,d])
                        # Position update (2.2)
                        X[i,d] = c1 * r1 *(Xgb[0,d] - A * Dx) + c2 * r2 * X[i,d]
                        # Boundary
                        X[i,d] = boundary(X[i,d], lb[0,d], ub[0,d])
                
                # {2} Search for prey
                elif abs(A) >= 1:
                    for d in range(dim):
                        # Select a random whale
                        k      = np.random.randint(low = 0, high = N)
                        # Compute D (2.7)
                        Dx     = abs(C * X[k,d] - X[i,d])
                        # Position update (2.8)
                        X[i,d] = X[k,d] - A * Dx
                        # Boundary
                        X[i,d] = boundary(X[i,d], lb[0,d], ub[0,d])
            
            # {3} Bubble-net attacking 
            elif p >= 0.5:
                for d in range(dim):
                    # Distance of whale to prey
                    dist   = abs(Xgb[0,d] - X[i,d])
                    # Position update (2.5)
                    X[i,d] = dist * np.exp(b * l) * np.cos(2 * np.pi * l) + Xgb[0,d] 
                    # Boundary
                    X[i,d] = boundary(X[i,d], lb[0,d], ub[0,d])
        
        # Binary conversion
        Xbin = binary_conversion(X, thres, N, dim)
        
        # Fitness
        for i in range(N):
            fit[i,0] = Fun(features, target, Xbin[i,:], opts)
            if fit[i,0] < fitG:
                Xgb[0,:] = X[i,:]
                fitG     = fit[i,0]
        
        # Store result
        curve[0,t] = fitG.copy()
        print("Generation:", t + 1)
        print("Best (WOA_PSO):", curve[0,t])
        t += 1            

            
    # Best feature subset
    Gbin       = binary_conversion(Xgb, thres, 1, dim) 
    Gbin       = Gbin.reshape(dim)    
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    num_feat   = len(sel_index)
    # Create dictionary
    woa_data = {'sf': sel_index, 'c': curve, 'nf': num_feat}
    
    return woa_data

# %%
column_headers = ['Type', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols',
                  'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color Intensity',
                   'Hue', 'OD280/OD315 of diluted wines', 'Proline']

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None, names=column_headers)
data = data.values
data
# Out:
# array([[1.000e+00, 1.423e+01, 1.710e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.000e+00, 1.320e+01, 1.780e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.000e+00, 1.316e+01, 2.360e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [3.000e+00, 1.327e+01, 4.280e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [3.000e+00, 1.317e+01, 2.590e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [3.000e+00, 1.413e+01, 4.100e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
features  = np.asarray(data[:, 1:])
target = np.asarray(data[:, 0])

# %%
num_runs = 20    # number of independent runs
k        = 5     # k-value in KNN
N        = 5     # number of particles
T        = 20    # maximum number of iterations
cv       = 10    # K-fold cross-validation
opts     = {'k':k, 'N':N, 'T':T, 'cv': cv}
dim      = features.shape[1]

# %%
acc_arr          = []
feature_size_arr = []
run_count        = 0

while run_count < num_runs:
  run_count += 1
  print("Run ", run_count)
  print("-----------------------------------")
  fmdl = woaPso(features, target, opts)
  sf   = fmdl['sf']
  
  if sf.size == 0:
    sf = np.arange(dim)
    
  print("SF", sf)

  kf = KFold(n_splits=cv, shuffle=True, random_state=2)

  total_Acc = 0

  for train_index, test_index in kf.split(features):
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = target[train_index], target[test_index]

    # Number of instances
    num_train = np.size(X_train, 0)
    num_test  = np.size(X_test, 0)
    
    # Define selected features
    xtrain = X_train[:, sf]
    ytrain = y_train.reshape(num_train)
    xtest  = X_test[:, sf]
    ytest  = y_test.reshape(num_test)

    # Training
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(xtrain, ytrain)

    # Prediction
    ypred = knn.predict(xtest)
    acc   = np.sum(ytest == ypred) / num_test

    total_Acc = total_Acc + acc

  Accuracy = 100 * (total_Acc/cv)
  print("Accuracy:", Accuracy)
  acc_arr.append(Accuracy)

  num_feat = fmdl['nf']
  print("Feature Size:", num_feat)
  feature_size_arr.append(num_feat)
  print("--------------------------------------------------")
# Out:
# Run  1
# -----------------------------------
# Generation: 1
# Best (WOA): 0.19092533936651587
# Generation: 2
# Best (WOA_PSO): 0.12395475113122173
# Generation: 3
# Best (WOA_PSO): 0.12395475113122173
# Generation: 4
# Best (WOA_PSO): 0.12395475113122173
# Generation: 5
# Best (WOA_PSO): 0.09742533936651586
# Generation: 6
# Best (WOA_PSO): 0.09742533936651586
# Generation: 7
# Best (WOA_PSO): 0.09742533936651586
# Generation: 8
# Best (WOA_PSO): 0.09249321266968327
# Generation: 9
# Best (WOA_PSO): 0.09249321266968327
# Generation: 10
# Best (WOA_PSO): 0.09249321266968327
# Generation: 11
# Best (WOA_PSO): 0.07093891402714934
# Generation: 12
# Best (WOA_PSO): 0.07093891402714934
# Generation: 13
# Best (WOA_PSO): 0.07093891402714934
# Generation: 14
# Best (WOA_PSO): 0.07093891402714934
# Generation: 15
# Best (WOA_PSO): 0.07093891402714934
# Generation: 16
# Best (WOA_PSO): 0.07093891402714934
# Generation: 17
# Best (WOA_PSO): 0.06972398190045251
# Generation: 18
# Best (WOA_PSO): 0.06972398190045251
# Generation: 19
# Best (WOA_PSO): 0.06972398190045251
# Generation: 20
# Best (WOA_PSO): 0.06972398190045251
# SF [ 2  3 10 11]
# Accuracy: 82.02614379084967
# Feature Size: 4
# --------------------------------------------------
# Run  2
# -----------------------------------
# Generation: 1
# Best (WOA): 0.08181674208144799
# Generation: 2
# Best (WOA_PSO): 0.08181674208144799
# Generation: 3
# Best (WOA_PSO): 0.08181674208144799
# Generation: 4
# Best (WOA_PSO): 0.08181674208144799
# Generation: 5
# Best (WOA_PSO): 0.08181674208144799
# Generation: 6
# Best (WOA_PSO): 0.08181674208144799
# Generation: 7
# Best (WOA_PSO): 0.06026244343891405
# Generation: 8
# Best (WOA_PSO): 0.06026244343891405
# Generation: 9
# Best (WOA_PSO): 0.06026244343891405
# Generation: 10
# Best (WOA_PSO): 0.06026244343891405
# Generation: 11
# Best (WOA_PSO): 0.05443891402714934
# Generation: 12
# Best (WOA_PSO): 0.05443891402714934
# Generation: 13
# Best (WOA_PSO): 0.05443891402714934
# Generation: 14
# Best (WOA_PSO): 0.05443891402714934
# Generation: 15
# Best (WOA_PSO): 0.05443891402714934
# Generation: 16
# Best (WOA_PSO): 0.05443891402714934
# Generation: 17
# Best (WOA_PSO): 0.05443891402714934
# Generation: 18
# Best (WOA_PSO): 0.05443891402714934
# Generation: 19
# Best (WOA_PSO): 0.05443891402714934
# Generation: 20
# Best (WOA_PSO): 0.05443891402714934
# SF [ 4  5 12]
# Accuracy: 68.62745098039215
# Feature Size: 3
# --------------------------------------------------
# Run  3
# -----------------------------------
# Generation: 1
# Best (WOA): 0.18510180995475117
# Generation: 2
# Best (WOA_PSO): 0.18510180995475117
# Generation: 3
# Best (WOA_PSO): 0.18510180995475117
# Generation: 4
# Best (WOA_PSO): 0.07457692307692311
# Generation: 5
# Best (WOA_PSO): 0.06730090497737559
# Generation: 6
# Best (WOA_PSO): 0.06730090497737559
# Generation: 7
# Best (WOA_PSO): 0.06730090497737559
# Generation: 8
# Best (WOA_PSO): 0.06730090497737559
# Generation: 9
# Best (WOA_PSO): 0.06730090497737559
# Generation: 10
# Best (WOA_PSO): 0.06576244343891405
# Generation: 11
# Best (WOA_PSO): 0.06576244343891405
# Generation: 12
# Best (WOA_PSO): 0.05411538461538464
# Generation: 13
# Best (WOA_PSO): 0.05411538461538464
# Generation: 14
# Best (WOA_PSO): 0.05411538461538464
# Generation: 15
# Best (WOA_PSO): 0.05411538461538464
# Generation: 16
# Best (WOA_PSO): 0.05411538461538464
# Generation: 17
# Best (WOA_PSO): 0.05411538461538464
# Generation: 18
# Best (WOA_PSO): 0.05411538461538464
# Generation: 19
# Best (WOA_PSO): 0.05411538461538464
# Generation: 20
# Best (WOA_PSO): 0.05411538461538464
# SF [ 1  4  5  6  7  9 11 12]
# Accuracy: 69.73856209150327
# Feature Size: 8
# --------------------------------------------------
# Run  4
# -----------------------------------
# Generation: 1
# Best (WOA): 0.04926244343891405
# Generation: 2
# Best (WOA_PSO): 0.04926244343891405
# Generation: 3
# Best (WOA_PSO): 0.04926244343891405
# Generation: 4
# Best (WOA_PSO): 0.04926244343891405
# Generation: 5
# Best (WOA_PSO): 0.04926244343891405
# Generation: 6
# Best (WOA_PSO): 0.04926244343891405
# Generation: 7
# Best (WOA_PSO): 0.04926244343891405
# Generation: 8
# Best (WOA_PSO): 0.04926244343891405
# Generation: 9
# Best (WOA_PSO): 0.04926244343891405
# Generation: 10
# Best (WOA_PSO): 0.04926244343891405
# Generation: 11
# Best (WOA_PSO): 0.04926244343891405
# Generation: 12
# Best (WOA_PSO): 0.04926244343891405
# Generation: 13
# Best (WOA_PSO): 0.04926244343891405
# Generation: 14
# Best (WOA_PSO): 0.04926244343891405
# Generation: 15
# Best (WOA_PSO): 0.04926244343891405
# Generation: 16
# Best (WOA_PSO): 0.04816968325791858
# Generation: 17
# Best (WOA_PSO): 0.04816968325791858
# Generation: 18
# Best (WOA_PSO): 0.04816968325791858
# Generation: 19
# Best (WOA_PSO): 0.04816968325791858
# Generation: 20
# Best (WOA_PSO): 0.04816968325791858
# SF [ 0  2  3  7  8 10 11 12]
# Accuracy: 66.92810457516339
# Feature Size: 8
# --------------------------------------------------
# Run  5
# -----------------------------------
# Generation: 1
# Best (WOA): 0.16872398190045249
# Generation: 2
# Best (WOA_PSO): 0.11833257918552037
# Generation: 3
# Best (WOA_PSO): 0.10349321266968325
# Generation: 4
# Best (WOA_PSO): 0.10349321266968325
# Generation: 5
# Best (WOA_PSO): 0.10349321266968325
# Generation: 6
# Best (WOA_PSO): 0.10349321266968325
# Generation: 7
# Best (WOA_PSO): 0.10349321266968325
# Generation: 8
# Best (WOA_PSO): 0.06466968325791857
# Generation: 9
# Best (WOA_PSO): 0.06466968325791857
# Generation: 10
# Best (WOA_PSO): 0.06466968325791857
# Generation: 11
# Best (WOA_PSO): 0.06466968325791857
# Generation: 12
# Best (WOA_PSO): 0.06466968325791857
# Generation: 13
# Best (WOA_PSO): 0.06466968325791857
# Generation: 14
# Best (WOA_PSO): 0.06466968325791857
# Generation: 15
# Best (WOA_PSO): 0.06466968325791857
# Generation: 16
# Best (WOA_PSO): 0.06466968325791857
# Generation: 17
# Best (WOA_PSO): 0.06466968325791857
# Generation: 18
# Best (WOA_PSO): 0.06466968325791857
# Generation: 19
# Best (WOA_PSO): 0.06466968325791857
# Generation: 20
# Best (WOA_PSO): 0.06466968325791857
# SF [0 3 4 6 8]
# Accuracy: 74.83660130718954
# Feature Size: 5
# --------------------------------------------------
# Run  6
# -----------------------------------
# Generation: 1
# Best (WOA): 0.05257692307692309
# Generation: 2
# Best (WOA_PSO): 0.05257692307692309
# Generation: 3
# Best (WOA_PSO): 0.05257692307692309
# Generation: 4
# Best (WOA_PSO): 0.05257692307692309
# Generation: 5
# Best (WOA_PSO): 0.05257692307692309
# Generation: 6
# Best (WOA_PSO): 0.05257692307692309
# Generation: 7
# Best (WOA_PSO): 0.05257692307692309
# Generation: 8
# Best (WOA_PSO): 0.05257692307692309
# Generation: 9
# Best (WOA_PSO): 0.05015384615384619
# Generation: 10
# Best (WOA_PSO): 0.05015384615384619
# Generation: 11
# Best (WOA_PSO): 0.05015384615384619
# Generation: 12
# Best (WOA_PSO): 0.05015384615384619
# Generation: 13
# Best (WOA_PSO): 0.05015384615384619
# Generation: 14
# Best (WOA_PSO): 0.05015384615384619
# Generation: 15
# Best (WOA_PSO): 0.05015384615384619
# Generation: 16
# Best (WOA_PSO): 0.05015384615384619
# Generation: 17
# Best (WOA_PSO): 0.05015384615384619
# Generation: 18
# Best (WOA_PSO): 0.05015384615384619
# Generation: 19
# Best (WOA_PSO): 0.05015384615384619
# Generation: 20
# Best (WOA_PSO): 0.05015384615384619
# SF [ 0  4  6  8  9 12]
# Accuracy: 69.73856209150327
# Feature Size: 6
# --------------------------------------------------
# Run  7
# -----------------------------------
# Generation: 1
# Best (WOA): 0.06434615384615387
# Generation: 2
# Best (WOA_PSO): 0.06434615384615387
# Generation: 3
# Best (WOA_PSO): 0.06434615384615387
# Generation: 4
# Best (WOA_PSO): 0.06434615384615387
# Generation: 5
# Best (WOA_PSO): 0.05399321266968328
# Generation: 6
# Best (WOA_PSO): 0.05399321266968328
# Generation: 7
# Best (WOA_PSO): 0.05399321266968328
# Generation: 8
# Best (WOA_PSO): 0.05399321266968328
# Generation: 9
# Best (WOA_PSO): 0.05399321266968328
# Generation: 10
# Best (WOA_PSO): 0.05399321266968328
# Generation: 11
# Best (WOA_PSO): 0.05257692307692309
# Generation: 12
# Best (WOA_PSO): 0.05257692307692309
# Generation: 13
# Best (WOA_PSO): 0.05257692307692309
# Generation: 14
# Best (WOA_PSO): 0.05257692307692309
# Generation: 15
# Best (WOA_PSO): 0.05257692307692309
# Generation: 16
# Best (WOA_PSO): 0.05257692307692309
# Generation: 17
# Best (WOA_PSO): 0.05257692307692309
# Generation: 18
# Best (WOA_PSO): 0.05257692307692309
# Generation: 19
# Best (WOA_PSO): 0.05257692307692309
# Generation: 20
# Best (WOA_PSO): 0.05257692307692309
# SF [2 3 5 6 7 9]
# Accuracy: 90.45751633986929
# Feature Size: 6
# --------------------------------------------------
# Run  8
# -----------------------------------
# Generation: 1
# Best (WOA): 0.1024004524886878
# Generation: 2
# Best (WOA_PSO): 0.07081674208144799
# Generation: 3
# Best (WOA_PSO): 0.07081674208144799
# Generation: 4
# Best (WOA_PSO): 0.07081674208144799
# Generation: 5
# Best (WOA_PSO): 0.07081674208144799
# Generation: 6
# Best (WOA_PSO): 0.07081674208144799
# Generation: 7
# Best (WOA_PSO): 0.05884615384615387
# Generation: 8
# Best (WOA_PSO): 0.05884615384615387
# Generation: 9
# Best (WOA_PSO): 0.05884615384615387
# Generation: 10
# Best (WOA_PSO): 0.05884615384615387
# Generation: 11
# Best (WOA_PSO): 0.05884615384615387
# Generation: 12
# Best (WOA_PSO): 0.05884615384615387
# Generation: 13
# Best (WOA_PSO): 0.05884615384615387
# Generation: 14
# Best (WOA_PSO): 0.05884615384615387
# Generation: 15
# Best (WOA_PSO): 0.05884615384615387
# Generation: 16
# Best (WOA_PSO): 0.05884615384615387
# Generation: 17
# Best (WOA_PSO): 0.05884615384615387
# Generation: 18
# Best (WOA_PSO): 0.05884615384615387
# Generation: 19
# Best (WOA_PSO): 0.05884615384615387
# Generation: 20
# Best (WOA_PSO): 0.05884615384615387
# SF [0 1 3 5 6 9]
# Accuracy: 93.88888888888889
# Feature Size: 6
# --------------------------------------------------
# Run  9
# -----------------------------------
# Generation: 1
# Best (WOA): 0.08743891402714933
# Generation: 2
# Best (WOA_PSO): 0.08743891402714933
# Generation: 3
# Best (WOA_PSO): 0.08666968325791856
# Generation: 4
# Best (WOA_PSO): 0.08666968325791856
# Generation: 5
# Best (WOA_PSO): 0.0865475113122172
# Generation: 6
# Best (WOA_PSO): 0.0865475113122172
# Generation: 7
# Best (WOA_PSO): 0.08577828054298646
# Generation: 8
# Best (WOA_PSO): 0.08577828054298646
# Generation: 9
# Best (WOA_PSO): 0.08577828054298646
# Generation: 10
# Best (WOA_PSO): 0.08577828054298646
# Generation: 11
# Best (WOA_PSO): 0.08577828054298646
# Generation: 12
# Best (WOA_PSO): 0.08577828054298646
# Generation: 13
# Best (WOA_PSO): 0.08577828054298646
# Generation: 14
# Best (WOA_PSO): 0.08577828054298646
# Generation: 15
# Best (WOA_PSO): 0.08577828054298646
# Generation: 16
# Best (WOA_PSO): 0.07081674208144799
# Generation: 17
# Best (WOA_PSO): 0.06830769230769233
# Generation: 18
# Best (WOA_PSO): 0.06830769230769233
# Generation: 19
# Best (WOA_PSO): 0.06830769230769233
# Generation: 20
# Best (WOA_PSO): 0.06830769230769233
# SF [1 6 8]
# Accuracy: 81.5686274509804
# Feature Size: 3
# --------------------------------------------------
# Run  10
# -----------------------------------
# Generation: 1
# Best (WOA): 0.19246380090497742
# Generation: 2
# Best (WOA_PSO): 0.08820814479638012
# Generation: 3
# Best (WOA_PSO): 0.0841244343891403
# Generation: 4
# Best (WOA_PSO): 0.05981674208144799
# Generation: 5
# Best (WOA_PSO): 0.05981674208144799
# Generation: 6
# Best (WOA_PSO): 0.05981674208144799
# Generation: 7
# Best (WOA_PSO): 0.05981674208144799
# Generation: 8
# Best (WOA_PSO): 0.05981674208144799
# Generation: 9
# Best (WOA_PSO): 0.05981674208144799
# Generation: 10
# Best (WOA_PSO): 0.05981674208144799
# Generation: 11
# Best (WOA_PSO): 0.05981674208144799
# Generation: 12
# Best (WOA_PSO): 0.05981674208144799
# Generation: 13
# Best (WOA_PSO): 0.05981674208144799
# Generation: 14
# Best (WOA_PSO): 0.05981674208144799
# Generation: 15
# Best (WOA_PSO): 0.05981674208144799
# Generation: 16
# Best (WOA_PSO): 0.05981674208144799
# Generation: 17
# Best (WOA_PSO): 0.05981674208144799
# Generation: 18
# Best (WOA_PSO): 0.05981674208144799
# Generation: 19
# Best (WOA_PSO): 0.05981674208144799
# Generation: 20
# Best (WOA_PSO): 0.05981674208144799
# SF [0 3 4 5 9]
# Accuracy: 80.45751633986929
# Feature Size: 5
# --------------------------------------------------
# Run  11
# -----------------------------------
# Generation: 1
# Best (WOA): 0.2921108597285068
# Generation: 2
# Best (WOA_PSO): 0.14340950226244348
# Generation: 3
# Best (WOA_PSO): 0.09050904977375569
# Generation: 4
# Best (WOA_PSO): 0.09050904977375569
# Generation: 5
# Best (WOA_PSO): 0.09050904977375569
# Generation: 6
# Best (WOA_PSO): 0.09050904977375569
# Generation: 7
# Best (WOA_PSO): 0.09050904977375569
# Generation: 8
# Best (WOA_PSO): 0.09050904977375569
# Generation: 9
# Best (WOA_PSO): 0.09050904977375569
# Generation: 10
# Best (WOA_PSO): 0.09050904977375569
# Generation: 11
# Best (WOA_PSO): 0.09050904977375569
# Generation: 12
# Best (WOA_PSO): 0.08116968325791858
# Generation: 13
# Best (WOA_PSO): 0.08116968325791858
# Generation: 14
# Best (WOA_PSO): 0.08116968325791858
# Generation: 15
# Best (WOA_PSO): 0.08116968325791858
# Generation: 16
# Best (WOA_PSO): 0.07016968325791856
# Generation: 17
# Best (WOA_PSO): 0.06940045248868779
# Generation: 18
# Best (WOA_PSO): 0.06940045248868779
# Generation: 19
# Best (WOA_PSO): 0.06940045248868779
# Generation: 20
# Best (WOA_PSO): 0.06940045248868779
# SF [4 6 7 9]
# Accuracy: 80.98039215686275
# Feature Size: 4
# --------------------------------------------------
# Run  12
# -----------------------------------
# Generation: 1
# Best (WOA): 0.1299004524886878
# Generation: 2
# Best (WOA_PSO): 0.1299004524886878
# Generation: 3
# Best (WOA_PSO): 0.06608597285067876
# Generation: 4
# Best (WOA_PSO): 0.06608597285067876
# Generation: 5
# Best (WOA_PSO): 0.06608597285067876
# Generation: 6
# Best (WOA_PSO): 0.06608597285067876
# Generation: 7
# Best (WOA_PSO): 0.06608597285067876
# Generation: 8
# Best (WOA_PSO): 0.06434615384615387
# Generation: 9
# Best (WOA_PSO): 0.06434615384615387
# Generation: 10
# Best (WOA_PSO): 0.06434615384615387
# Generation: 11
# Best (WOA_PSO): 0.06434615384615387
# Generation: 12
# Best (WOA_PSO): 0.06434615384615387
# Generation: 13
# Best (WOA_PSO): 0.06434615384615387
# Generation: 14
# Best (WOA_PSO): 0.06434615384615387
# Generation: 15
# Best (WOA_PSO): 0.06434615384615387
# Generation: 16
# Best (WOA_PSO): 0.06434615384615387
# Generation: 17
# Best (WOA_PSO): 0.06434615384615387
# Generation: 18
# Best (WOA_PSO): 0.06434615384615387
# Generation: 19
# Best (WOA_PSO): 0.06434615384615387
# Generation: 20
# Best (WOA_PSO): 0.06434615384615387
# SF [ 0  2 10]
# Accuracy: 86.50326797385623
# Feature Size: 3
# --------------------------------------------------
# Run  13
# -----------------------------------
# Generation: 1
# Best (WOA): 0.07599321266968329
# Generation: 2
# Best (WOA_PSO): 0.07599321266968329
# Generation: 3
# Best (WOA_PSO): 0.07599321266968329
# Generation: 4
# Best (WOA_PSO): 0.07599321266968329
# Generation: 5
# Best (WOA_PSO): 0.07599321266968329
# Generation: 6
# Best (WOA_PSO): 0.07599321266968329
# Generation: 7
# Best (WOA_PSO): 0.07599321266968329
# Generation: 8
# Best (WOA_PSO): 0.06422398190045252
# Generation: 9
# Best (WOA_PSO): 0.06422398190045252
# Generation: 10
# Best (WOA_PSO): 0.06422398190045252
# Generation: 11
# Best (WOA_PSO): 0.06422398190045252
# Generation: 12
# Best (WOA_PSO): 0.06422398190045252
# Generation: 13
# Best (WOA_PSO): 0.06422398190045252
# Generation: 14
# Best (WOA_PSO): 0.06422398190045252
# Generation: 15
# Best (WOA_PSO): 0.06422398190045252
# Generation: 16
# Best (WOA_PSO): 0.06422398190045252
# Generation: 17
# Best (WOA_PSO): 0.06422398190045252
# Generation: 18
# Best (WOA_PSO): 0.06422398190045252
# Generation: 19
# Best (WOA_PSO): 0.06422398190045252
# Generation: 20
# Best (WOA_PSO): 0.06422398190045252
# SF [ 0  4  5  8 10 12]
# Accuracy: 67.51633986928104
# Feature Size: 6
# --------------------------------------------------
# Run  14
# -----------------------------------
# Generation: 1
# Best (WOA): 0.09390950226244346
# Generation: 2
# Best (WOA_PSO): 0.09390950226244346
# Generation: 3
# Best (WOA_PSO): 0.09390950226244346
# Generation: 4
# Best (WOA_PSO): 0.09390950226244346
# Generation: 5
# Best (WOA_PSO): 0.09390950226244346
# Generation: 6
# Best (WOA_PSO): 0.09390950226244346
# Generation: 7
# Best (WOA_PSO): 0.09390950226244346
# Generation: 8
# Best (WOA_PSO): 0.09390950226244346
# Generation: 9
# Best (WOA_PSO): 0.08181674208144799
# Generation: 10
# Best (WOA_PSO): 0.08181674208144799
# Generation: 11
# Best (WOA_PSO): 0.08181674208144799
# Generation: 12
# Best (WOA_PSO): 0.08181674208144799
# Generation: 13
# Best (WOA_PSO): 0.07566968325791859
# Generation: 14
# Best (WOA_PSO): 0.07566968325791859
# Generation: 15
# Best (WOA_PSO): 0.07566968325791859
# Generation: 16
# Best (WOA_PSO): 0.07566968325791859
# Generation: 17
# Best (WOA_PSO): 0.07566968325791859
# Generation: 18
# Best (WOA_PSO): 0.07566968325791859
# Generation: 19
# Best (WOA_PSO): 0.07566968325791859
# Generation: 20
# Best (WOA_PSO): 0.07566968325791859
# SF [0 2 7 9]
# Accuracy: 81.5686274509804
# Feature Size: 4
# --------------------------------------------------
# Run  15
# -----------------------------------
# Generation: 1
# Best (WOA): 0.09710180995475116
# Generation: 2
# Best (WOA_PSO): 0.08666968325791857
# Generation: 3
# Best (WOA_PSO): 0.08666968325791857
# Generation: 4
# Best (WOA_PSO): 0.08666968325791857
# Generation: 5
# Best (WOA_PSO): 0.06543891402714935
# Generation: 6
# Best (WOA_PSO): 0.06543891402714935
# Generation: 7
# Best (WOA_PSO): 0.059493212669683285
# Generation: 8
# Best (WOA_PSO): 0.059493212669683285
# Generation: 9
# Best (WOA_PSO): 0.059493212669683285
# Generation: 10
# Best (WOA_PSO): 0.059493212669683285
# Generation: 11
# Best (WOA_PSO): 0.059493212669683285
# Generation: 12
# Best (WOA_PSO): 0.059493212669683285
# Generation: 13
# Best (WOA_PSO): 0.059493212669683285
# Generation: 14
# Best (WOA_PSO): 0.059493212669683285
# Generation: 15
# Best (WOA_PSO): 0.059493212669683285
# Generation: 16
# Best (WOA_PSO): 0.059493212669683285
# Generation: 17
# Best (WOA_PSO): 0.059493212669683285
# Generation: 18
# Best (WOA_PSO): 0.059493212669683285
# Generation: 19
# Best (WOA_PSO): 0.059493212669683285
# Generation: 20
# Best (WOA_PSO): 0.059493212669683285
# SF [ 0  1  2  7  8  9 10 12]
# Accuracy: 70.26143790849673
# Feature Size: 8
# --------------------------------------------------
# Run  16
# -----------------------------------
# Generation: 1
# Best (WOA): 0.09677828054298646
# Generation: 2
# Best (WOA_PSO): 0.09677828054298646
# Generation: 3
# Best (WOA_PSO): 0.09677828054298646
# Generation: 4
# Best (WOA_PSO): 0.09677828054298646
# Generation: 5
# Best (WOA_PSO): 0.09677828054298646
# Generation: 6
# Best (WOA_PSO): 0.09677828054298646
# Generation: 7
# Best (WOA_PSO): 0.09677828054298646
# Generation: 8
# Best (WOA_PSO): 0.07643891402714935
# Generation: 9
# Best (WOA_PSO): 0.07643891402714935
# Generation: 10
# Best (WOA_PSO): 0.07643891402714935
# Generation: 11
# Best (WOA_PSO): 0.07643891402714935
# Generation: 12
# Best (WOA_PSO): 0.07643891402714935
# Generation: 13
# Best (WOA_PSO): 0.07643891402714935
# Generation: 14
# Best (WOA_PSO): 0.07643891402714935
# Generation: 15
# Best (WOA_PSO): 0.07643891402714935
# Generation: 16
# Best (WOA_PSO): 0.07643891402714935
# Generation: 17
# Best (WOA_PSO): 0.07643891402714935
# Generation: 18
# Best (WOA_PSO): 0.07643891402714935
# Generation: 19
# Best (WOA_PSO): 0.07643891402714935
# Generation: 20
# Best (WOA_PSO): 0.06531674208144798
# SF [ 7  8 10]
# Accuracy: 70.7516339869281
# Feature Size: 3
# --------------------------------------------------
# Run  17
# -----------------------------------
# Generation: 1
# Best (WOA): 0.20390950226244345
# Generation: 2
# Best (WOA_PSO): 0.16496380090497742
# Generation: 3
# Best (WOA_PSO): 0.07004751131221722
# Generation: 4
# Best (WOA_PSO): 0.07004751131221722
# Generation: 5
# Best (WOA_PSO): 0.07004751131221722
# Generation: 6
# Best (WOA_PSO): 0.07004751131221722
# Generation: 7
# Best (WOA_PSO): 0.07004751131221722
# Generation: 8
# Best (WOA_PSO): 0.07004751131221722
# Generation: 9
# Best (WOA_PSO): 0.07004751131221722
# Generation: 10
# Best (WOA_PSO): 0.07004751131221722
# Generation: 11
# Best (WOA_PSO): 0.07004751131221722
# Generation: 12
# Best (WOA_PSO): 0.07004751131221722
# Generation: 13
# Best (WOA_PSO): 0.07004751131221722
# Generation: 14
# Best (WOA_PSO): 0.07004751131221722
# Generation: 15
# Best (WOA_PSO): 0.07004751131221722
# Generation: 16
# Best (WOA_PSO): 0.07004751131221722
# Generation: 17
# Best (WOA_PSO): 0.07004751131221722
# Generation: 18
# Best (WOA_PSO): 0.07004751131221722
# Generation: 19
# Best (WOA_PSO): 0.07004751131221722
# Generation: 20
# Best (WOA_PSO): 0.07004751131221722
# SF [ 1  4  5  6 12]
# Accuracy: 70.29411764705881
# Feature Size: 5
# --------------------------------------------------
# Run  18
# -----------------------------------
# Generation: 1
# Best (WOA): 0.07708597285067877
# Generation: 2
# Best (WOA_PSO): 0.0717081447963801
# Generation: 3
# Best (WOA_PSO): 0.0717081447963801
# Generation: 4
# Best (WOA_PSO): 0.0717081447963801
# Generation: 5
# Best (WOA_PSO): 0.0717081447963801
# Generation: 6
# Best (WOA_PSO): 0.06830769230769233
# Generation: 7
# Best (WOA_PSO): 0.06830769230769233
# Generation: 8
# Best (WOA_PSO): 0.06830769230769233
# Generation: 9
# Best (WOA_PSO): 0.06830769230769233
# Generation: 10
# Best (WOA_PSO): 0.06830769230769233
# Generation: 11
# Best (WOA_PSO): 0.06830769230769233
# Generation: 12
# Best (WOA_PSO): 0.06830769230769233
# Generation: 13
# Best (WOA_PSO): 0.06830769230769233
# Generation: 14
# Best (WOA_PSO): 0.06830769230769233
# Generation: 15
# Best (WOA_PSO): 0.06830769230769233
# Generation: 16
# Best (WOA_PSO): 0.06830769230769233
# Generation: 17
# Best (WOA_PSO): 0.06830769230769233
# Generation: 18
# Best (WOA_PSO): 0.06830769230769233
# Generation: 19
# Best (WOA_PSO): 0.06830769230769233
# Generation: 20
# Best (WOA_PSO): 0.06830769230769233
# SF [ 2  4  6  7 10 11]
# Accuracy: 74.281045751634
# Feature Size: 6
# --------------------------------------------------
# Run  19
# -----------------------------------
# Generation: 1
# Best (WOA): 0.07158597285067876
# Generation: 2
# Best (WOA_PSO): 0.07158597285067876
# Generation: 3
# Best (WOA_PSO): 0.07158597285067876
# Generation: 4
# Best (WOA_PSO): 0.07158597285067876
# Generation: 5
# Best (WOA_PSO): 0.07158597285067876
# Generation: 6
# Best (WOA_PSO): 0.07158597285067876
# Generation: 7
# Best (WOA_PSO): 0.07158597285067876
# Generation: 8
# Best (WOA_PSO): 0.06543891402714934
# Generation: 9
# Best (WOA_PSO): 0.06543891402714934
# Generation: 10
# Best (WOA_PSO): 0.06543891402714934
# Generation: 11
# Best (WOA_PSO): 0.06543891402714934
# Generation: 12
# Best (WOA_PSO): 0.06543891402714934
# Generation: 13
# Best (WOA_PSO): 0.06543891402714934
# Generation: 14
# Best (WOA_PSO): 0.06466968325791857
# Generation: 15
# Best (WOA_PSO): 0.06466968325791857
# Generation: 16
# Best (WOA_PSO): 0.06466968325791857
# Generation: 17
# Best (WOA_PSO): 0.06466968325791857
# Generation: 18
# Best (WOA_PSO): 0.06466968325791857
# Generation: 19
# Best (WOA_PSO): 0.06466968325791857
# Generation: 20
# Best (WOA_PSO): 0.06466968325791857
# SF [1 2 3 4 5 6 7 9]
# Accuracy: 82.05882352941177
# Feature Size: 8
# --------------------------------------------------
# Run  20
# -----------------------------------
# Generation: 1
# Best (WOA): 0.1768552036199095
# Generation: 2
# Best (WOA_PSO): 0.07643891402714935
# Generation: 3
# Best (WOA_PSO): 0.07643891402714935
# Generation: 4
# Best (WOA_PSO): 0.06313122171945704
# Generation: 5
# Best (WOA_PSO): 0.06313122171945704
# Generation: 6
# Best (WOA_PSO): 0.06313122171945704
# Generation: 7
# Best (WOA_PSO): 0.06313122171945704
# Generation: 8
# Best (WOA_PSO): 0.06313122171945704
# Generation: 9
# Best (WOA_PSO): 0.06313122171945704
# Generation: 10
# Best (WOA_PSO): 0.06313122171945704
# Generation: 11
# Best (WOA_PSO): 0.06313122171945704
# Generation: 12
# Best (WOA_PSO): 0.06313122171945704
# Generation: 13
# Best (WOA_PSO): 0.06313122171945704
# Generation: 14
# Best (WOA_PSO): 0.06313122171945704
# Generation: 15
# Best (WOA_PSO): 0.06038461538461541
# Generation: 16
# Best (WOA_PSO): 0.06038461538461541
# Generation: 17
# Best (WOA_PSO): 0.06038461538461541
# Generation: 18
# Best (WOA_PSO): 0.06038461538461541
# Generation: 19
# Best (WOA_PSO): 0.06038461538461541
# Generation: 20
# Best (WOA_PSO): 0.06038461538461541
# SF [ 4  5 10 11]
# Accuracy: 69.18300653594771
# Feature Size: 4
# --------------------------------------------------

# %%
print("Average Accuracy: ", np.mean(acc_arr))
print("Average number of features selected: ", np.mean(feature_size_arr))
# Out:
# Average Accuracy:  76.58333333333333
# Average number of features selected:  5.25

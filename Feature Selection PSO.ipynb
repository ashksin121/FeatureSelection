# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from numpy.random import rand
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
def error_rate(features, target, x, opts):
    # parameters
    k     = opts['k']
    cv    = opts['cv']

    kf = KFold(n_splits=cv, shuffle=True, random_state=2)

    total_error = 0

    for train_index, test_index in kf.split(features):
      X_train, X_test = features[train_index], features[test_index]
      y_train, y_test = target[train_index], target[test_index]

      # Number of instances
      num_train = np.size(X_train, 0)
      num_test  = np.size(X_test, 0)
      
      # Define selected features
      xtrain = X_train[:, x==1]
      ytrain = y_train.reshape(num_train)
      xtest  = X_test[:, x==1]
      ytest  = y_test.reshape(num_test)

      # Training
      knn = KNeighborsClassifier(n_neighbors=k)
      knn.fit(xtrain, ytrain)

      # Prediction
      ypred = knn.predict(xtest)
      acc   = np.sum(ytest == ypred) / num_test
      error = 1 - acc

      total_error = total_error + error
      
    return total_error/cv

# %%
def Fun(features, target, x, opts):
    # Parameters
    alpha    = 0.99
    beta     = 1 - alpha
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if num_feat == 0:
        cost  = 1
    else:
        # Get error rate
        error = error_rate(features, target, x, opts)
        # Objective function
        cost  = alpha * error + beta * (num_feat / max_feat)
        
    return cost

# %%
def init_position(lb, ub, N, dim):
    X = np.zeros([N, dim], dtype='float')
    for i in range(N):
        for d in range(dim):
            X[i,d] = lb[0,d] + (ub[0,d] - lb[0,d]) * rand()        
    
    return X

# %%
def init_velocity(lb, ub, N, dim):
    V    = np.zeros([N, dim], dtype='float')
    Vmax = np.zeros([1, dim], dtype='float')
    Vmin = np.zeros([1, dim], dtype='float')
    # Maximum & minimum velocity
    for d in range(dim):
        Vmax[0,d] = (ub[0,d] - lb[0,d]) / 2
        Vmin[0,d] = -Vmax[0,d]
        
    for i in range(N):
        for d in range(dim):
            V[i,d] = Vmin[0,d] + (Vmax[0,d] - Vmin[0,d]) * rand()
        
    return V, Vmax, Vmin

# %%
def binary_conversion(X, thres, N, dim):
    Xbin = np.zeros([N, dim], dtype='int')
    for i in range(N):
        for d in range(dim):
            xi = 1/(1 + np.exp(-X[i,d]))
            # if xi > thres:
            if X[i,d] > 0.5:
                Xbin[i,d] = 1
            else:
                Xbin[i,d] = 0
    
    return Xbin

# %%
def boundary(x, lb, ub):
    if x < lb:
        x = lb
    if x > ub:
        x = ub
    
    return x

# %%
def pso(features, target, opts):
    # Parameters
    ub    = 1
    lb    = 0
    thres = rand()    # NEED TO CHANGE
    w     = 0.9       # inertia weight
    c1    = 2         # acceleration factor
    c2    = 2         # acceleration factor
    
    print(thres)

    N        = opts['N']
    max_iter = opts['T']
    if 'w' in opts:
        w    = opts['w']
    if 'c1' in opts:
        c1   = opts['c1']
    if 'c2' in opts:
        c2   = opts['c2'] 
    
    # Dimension
    dim = np.size(features, 1)
    if np.size(lb) == 1:
        ub = ub * np.ones([1, dim], dtype='float')
        lb = lb * np.ones([1, dim], dtype='float')
        
    # Initialize position & velocity
    X             = init_position(lb, ub, N, dim)
    V, Vmax, Vmin = init_velocity(lb, ub, N, dim) 
    
    # Pre
    fit   = np.zeros([N, 1], dtype='float')
    Xgb   = np.zeros([1, dim], dtype='float')
    fitG  = float('inf')
    Xpb   = np.zeros([N, dim], dtype='float')
    fitP  = float('inf') * np.ones([N, 1], dtype='float')
    curve = np.zeros([1, max_iter], dtype='float') 
    t     = 0
    
    while t < max_iter:
        # Binary conversion
        Xbin = binary_conversion(X, thres, N, dim)
        
        # Fitness
        for i in range(N):
            fit[i,0] = Fun(features, target, Xbin[i,:], opts)
            if fit[i,0] < fitP[i,0]:
                Xpb[i,:]  = X[i,:]
                fitP[i,0] = fit[i,0]
            if fitP[i,0] < fitG:
                Xgb[0,:]  = Xpb[i,:]
                fitG      = fitP[i,0]
        
        # Store result
        curve[0,t] = fitG.copy()
        print("Iteration:", t + 1)
        print("Best (PSO):", curve[0,t])
        t += 1
        
        for i in range(N):
            for d in range(dim):
                # Update velocity
                r1     = rand()
                r2     = rand()
                V[i,d] = w * V[i,d] + c1 * r1 * (Xpb[i,d] - X[i,d]) + c2 * r2 * (Xgb[0,d] - X[i,d]) 
                # Boundary
                V[i,d] = boundary(V[i,d], Vmin[0,d], Vmax[0,d])
                # Update position
                X[i,d] = X[i,d] + V[i,d]
                # Boundary
                X[i,d] = boundary(X[i,d], lb[0,d], ub[0,d])
    
                
    # Best feature subset
    Gbin       = binary_conversion(Xgb, thres, 1, dim) 
    Gbin       = Gbin.reshape(dim)
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    num_feat   = len(sel_index)
    # Create dictionary
    pso_data = {'sf': sel_index, 'c': curve, 'nf': num_feat}
    
    return pso_data

# %%
column_headers = ['Type', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols',
                  'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color Intensity',
                   'Hue', 'OD280/OD315 of diluted wines', 'Proline']

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None, names=column_headers)
data = data.values
data
# Out:
# array([[1.000e+00, 1.423e+01, 1.710e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.000e+00, 1.320e+01, 1.780e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.000e+00, 1.316e+01, 2.360e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [3.000e+00, 1.327e+01, 4.280e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [3.000e+00, 1.317e+01, 2.590e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [3.000e+00, 1.413e+01, 4.100e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
features  = np.asarray(data[:, 1:])
target = np.asarray(data[:, 0])

# %%
num_runs = 20    # number of independent runs
k        = 5     # k-value in KNN
N        = 5     # number of particles
T        = 20    # maximum number of iterations
cv       = 10    # K-fold cross-validation
opts     = {'k':k, 'N':N, 'T':T, 'cv': cv}
dim      = features.shape[1]

# %%
acc_arr          = []
feature_size_arr = []
run_count        = 0

while run_count < num_runs:
  run_count += 1
  print("Run ", run_count)
  print("-----------------------------------")
  fmdl = pso(features, target, opts)
  sf   = fmdl['sf']
  
  if sf.size == 0:
    sf = np.arange(dim)
    
  print("SF", sf)

  kf = KFold(n_splits=cv, shuffle=True, random_state=2)

  total_Acc = 0

  for train_index, test_index in kf.split(features):
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = target[train_index], target[test_index]

    # Number of instances
    num_train = np.size(X_train, 0)
    num_test  = np.size(X_test, 0)
    
    # Define selected features
    xtrain = X_train[:, sf]
    ytrain = y_train.reshape(num_train)
    xtest  = X_test[:, sf]
    ytest  = y_test.reshape(num_test)

    # Training
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(xtrain, ytrain)

    # Prediction
    ypred = knn.predict(xtest)
    acc   = np.sum(ytest == ypred) / num_test

    total_Acc = total_Acc + acc

  Accuracy = 100 * (total_Acc/cv)
  print("Accuracy:", Accuracy)
  acc_arr.append(Accuracy)

  num_feat = fmdl['nf']
  print("Feature Size:", num_feat)
  feature_size_arr.append(num_feat)
  print("--------------------------------------------------")
# Out:
# Run  1
# -----------------------------------
# 0.9024242009632556
# Iteration: 1
# Best (PSO): 0.299472850678733
# Iteration: 2
# Best (PSO): 0.2987036199095023
# Iteration: 3
# Best (PSO): 0.2987036199095023
# Iteration: 4
# Best (PSO): 0.25328733031674217
# Iteration: 5
# Best (PSO): 0.15266968325791855
# Iteration: 6
# Best (PSO): 0.07643891402714936
# Iteration: 7
# Best (PSO): 0.07170814479638012
# Iteration: 8
# Best (PSO): 0.04311538461538463
# Iteration: 9
# Best (PSO): 0.04311538461538463
# Iteration: 10
# Best (PSO): 0.04311538461538463
# Iteration: 11
# Best (PSO): 0.04311538461538463
# Iteration: 12
# Best (PSO): 0.04311538461538463
# Iteration: 13
# Best (PSO): 0.04311538461538463
# Iteration: 14
# Best (PSO): 0.04311538461538463
# Iteration: 15
# Best (PSO): 0.04311538461538463
# Iteration: 16
# Best (PSO): 0.04311538461538463
# Iteration: 17
# Best (PSO): 0.04311538461538463
# Iteration: 18
# Best (PSO): 0.04311538461538463
# Iteration: 19
# Best (PSO): 0.04311538461538463
# Iteration: 20
# Best (PSO): 0.04311538461538463
# SF [ 0  2  5  6  8 10]
# Accuracy: 96.1111111111111
# Feature Size: 6
# --------------------------------------------------
# Run  2
# -----------------------------------
# 0.7282296167804048
# Iteration: 1
# Best (PSO): 0.2958348416289593
# Iteration: 2
# Best (PSO): 0.2958348416289593
# Iteration: 3
# Best (PSO): 0.2958348416289593
# Iteration: 4
# Best (PSO): 0.29506561085972854
# Iteration: 5
# Best (PSO): 0.29506561085972854
# Iteration: 6
# Best (PSO): 0.29429638009049774
# Iteration: 7
# Best (PSO): 0.29429638009049774
# Iteration: 8
# Best (PSO): 0.29429638009049774
# Iteration: 9
# Best (PSO): 0.29429638009049774
# Iteration: 10
# Best (PSO): 0.29429638009049774
# Iteration: 11
# Best (PSO): 0.29429638009049774
# Iteration: 12
# Best (PSO): 0.29429638009049774
# Iteration: 13
# Best (PSO): 0.29429638009049774
# Iteration: 14
# Best (PSO): 0.29429638009049774
# Iteration: 15
# Best (PSO): 0.29429638009049774
# Iteration: 16
# Best (PSO): 0.29429638009049774
# Iteration: 17
# Best (PSO): 0.29429638009049774
# Iteration: 18
# Best (PSO): 0.29429638009049774
# Iteration: 19
# Best (PSO): 0.29429638009049774
# Iteration: 20
# Best (PSO): 0.29429638009049774
# SF [ 1  3  8  9 10 11 12]
# Accuracy: 70.81699346405227
# Feature Size: 7
# --------------------------------------------------
# Run  3
# -----------------------------------
# 0.9437933444915696
# Iteration: 1
# Best (PSO): 0.06454751131221721
# Iteration: 2
# Best (PSO): 0.06454751131221721
# Iteration: 3
# Best (PSO): 0.06454751131221721
# Iteration: 4
# Best (PSO): 0.06454751131221721
# Iteration: 5
# Best (PSO): 0.06454751131221721
# Iteration: 6
# Best (PSO): 0.05366968325791857
# Iteration: 7
# Best (PSO): 0.05366968325791857
# Iteration: 8
# Best (PSO): 0.05366968325791857
# Iteration: 9
# Best (PSO): 0.05366968325791857
# Iteration: 10
# Best (PSO): 0.05366968325791857
# Iteration: 11
# Best (PSO): 0.05366968325791857
# Iteration: 12
# Best (PSO): 0.05366968325791857
# Iteration: 13
# Best (PSO): 0.05366968325791857
# Iteration: 14
# Best (PSO): 0.05366968325791857
# Iteration: 15
# Best (PSO): 0.05366968325791857
# Iteration: 16
# Best (PSO): 0.05366968325791857
# Iteration: 17
# Best (PSO): 0.05366968325791857
# Iteration: 18
# Best (PSO): 0.04926244343891405
# Iteration: 19
# Best (PSO): 0.04926244343891405
# Iteration: 20
# Best (PSO): 0.04926244343891405
# SF [0 2 5 6 8 9]
# Accuracy: 95.49019607843137
# Feature Size: 6
# --------------------------------------------------
# Run  4
# -----------------------------------
# 0.2476118461811937
# Iteration: 1
# Best (PSO): 0.2369095022624435
# Iteration: 2
# Best (PSO): 0.1473710407239819
# Iteration: 3
# Best (PSO): 0.05257692307692309
# Iteration: 4
# Best (PSO): 0.04234615384615387
# Iteration: 5
# Best (PSO): 0.04234615384615387
# Iteration: 6
# Best (PSO): 0.04234615384615387
# Iteration: 7
# Best (PSO): 0.04234615384615387
# Iteration: 8
# Best (PSO): 0.04234615384615387
# Iteration: 9
# Best (PSO): 0.04234615384615387
# Iteration: 10
# Best (PSO): 0.04234615384615387
# Iteration: 11
# Best (PSO): 0.04234615384615387
# Iteration: 12
# Best (PSO): 0.04234615384615387
# Iteration: 13
# Best (PSO): 0.04234615384615387
# Iteration: 14
# Best (PSO): 0.04234615384615387
# Iteration: 15
# Best (PSO): 0.04234615384615387
# Iteration: 16
# Best (PSO): 0.04234615384615387
# Iteration: 17
# Best (PSO): 0.04234615384615387
# Iteration: 18
# Best (PSO): 0.04234615384615387
# Iteration: 19
# Best (PSO): 0.04234615384615387
# Iteration: 20
# Best (PSO): 0.04234615384615387
# SF [ 0  2  6  7 10]
# Accuracy: 96.1111111111111
# Feature Size: 5
# --------------------------------------------------
# Run  5
# -----------------------------------
# 0.3649225611438597
# Iteration: 1
# Best (PSO): 0.11514027149321268
# Iteration: 2
# Best (PSO): 0.09677828054298646
# Iteration: 3
# Best (PSO): 0.05399321266968328
# Iteration: 4
# Best (PSO): 0.05399321266968328
# Iteration: 5
# Best (PSO): 0.05399321266968328
# Iteration: 6
# Best (PSO): 0.05399321266968328
# Iteration: 7
# Best (PSO): 0.05399321266968328
# Iteration: 8
# Best (PSO): 0.05399321266968328
# Iteration: 9
# Best (PSO): 0.05399321266968328
# Iteration: 10
# Best (PSO): 0.05399321266968328
# Iteration: 11
# Best (PSO): 0.05399321266968328
# Iteration: 12
# Best (PSO): 0.05399321266968328
# Iteration: 13
# Best (PSO): 0.05399321266968328
# Iteration: 14
# Best (PSO): 0.05399321266968328
# Iteration: 15
# Best (PSO): 0.05399321266968328
# Iteration: 16
# Best (PSO): 0.04740045248868781
# Iteration: 17
# Best (PSO): 0.04740045248868781
# Iteration: 18
# Best (PSO): 0.04740045248868781
# Iteration: 19
# Best (PSO): 0.04740045248868781
# Iteration: 20
# Best (PSO): 0.04740045248868781
# SF [0 6 8 9]
# Accuracy: 95.52287581699348
# Feature Size: 4
# --------------------------------------------------
# Run  6
# -----------------------------------
# 0.4816563261684833
# Iteration: 1
# Best (PSO): 0.17365610859728506
# Iteration: 2
# Best (PSO): 0.07049321266968327
# Iteration: 3
# Best (PSO): 0.07049321266968327
# Iteration: 4
# Best (PSO): 0.07049321266968327
# Iteration: 5
# Best (PSO): 0.0697239819004525
# Iteration: 6
# Best (PSO): 0.05916968325791856
# Iteration: 7
# Best (PSO): 0.05916968325791856
# Iteration: 8
# Best (PSO): 0.05916968325791856
# Iteration: 9
# Best (PSO): 0.05399321266968328
# Iteration: 10
# Best (PSO): 0.05399321266968328
# Iteration: 11
# Best (PSO): 0.05399321266968328
# Iteration: 12
# Best (PSO): 0.05399321266968328
# Iteration: 13
# Best (PSO): 0.05399321266968328
# Iteration: 14
# Best (PSO): 0.05399321266968328
# Iteration: 15
# Best (PSO): 0.05399321266968328
# Iteration: 16
# Best (PSO): 0.05399321266968328
# Iteration: 17
# Best (PSO): 0.05399321266968328
# Iteration: 18
# Best (PSO): 0.05399321266968328
# Iteration: 19
# Best (PSO): 0.05399321266968328
# Iteration: 20
# Best (PSO): 0.05399321266968328
# SF [0 2 6 8 9]
# Accuracy: 94.93464052287584
# Feature Size: 5
# --------------------------------------------------
# Run  7
# -----------------------------------
# 0.3836052069503315
# Iteration: 1
# Best (PSO): 0.18740950226244346
# Iteration: 2
# Best (PSO): 0.07126244343891405
# Iteration: 3
# Best (PSO): 0.07126244343891405
# Iteration: 4
# Best (PSO): 0.07126244343891405
# Iteration: 5
# Best (PSO): 0.07126244343891405
# Iteration: 6
# Best (PSO): 0.07126244343891405
# Iteration: 7
# Best (PSO): 0.07126244343891405
# Iteration: 8
# Best (PSO): 0.059493212669683285
# Iteration: 9
# Best (PSO): 0.059493212669683285
# Iteration: 10
# Best (PSO): 0.059493212669683285
# Iteration: 11
# Best (PSO): 0.059493212669683285
# Iteration: 12
# Best (PSO): 0.059493212669683285
# Iteration: 13
# Best (PSO): 0.059493212669683285
# Iteration: 14
# Best (PSO): 0.059493212669683285
# Iteration: 15
# Best (PSO): 0.059493212669683285
# Iteration: 16
# Best (PSO): 0.059493212669683285
# Iteration: 17
# Best (PSO): 0.059493212669683285
# Iteration: 18
# Best (PSO): 0.059493212669683285
# Iteration: 19
# Best (PSO): 0.059493212669683285
# Iteration: 20
# Best (PSO): 0.059493212669683285
# SF [0 1 5 6 9]
# Accuracy: 94.37908496732025
# Feature Size: 5
# --------------------------------------------------
# Run  8
# -----------------------------------
# 0.973146925365569
# Iteration: 1
# Best (PSO): 0.049384615384615416
# Iteration: 2
# Best (PSO): 0.049384615384615416
# Iteration: 3
# Best (PSO): 0.049384615384615416
# Iteration: 4
# Best (PSO): 0.049384615384615416
# Iteration: 5
# Best (PSO): 0.049384615384615416
# Iteration: 6
# Best (PSO): 0.049384615384615416
# Iteration: 7
# Best (PSO): 0.049384615384615416
# Iteration: 8
# Best (PSO): 0.049384615384615416
# Iteration: 9
# Best (PSO): 0.049384615384615416
# Iteration: 10
# Best (PSO): 0.048615384615384644
# Iteration: 11
# Best (PSO): 0.048615384615384644
# Iteration: 12
# Best (PSO): 0.048615384615384644
# Iteration: 13
# Best (PSO): 0.048615384615384644
# Iteration: 14
# Best (PSO): 0.048615384615384644
# Iteration: 15
# Best (PSO): 0.048615384615384644
# Iteration: 16
# Best (PSO): 0.048615384615384644
# Iteration: 17
# Best (PSO): 0.048615384615384644
# Iteration: 18
# Best (PSO): 0.048615384615384644
# Iteration: 19
# Best (PSO): 0.048615384615384644
# Iteration: 20
# Best (PSO): 0.048615384615384644
# SF [ 0  3  6  8  9 11]
# Accuracy: 95.55555555555554
# Feature Size: 6
# --------------------------------------------------
# Run  9
# -----------------------------------
# 0.39168906731579867
# Iteration: 1
# Best (PSO): 0.07753167420814483
# Iteration: 2
# Best (PSO): 0.07753167420814483
# Iteration: 3
# Best (PSO): 0.06608597285067876
# Iteration: 4
# Best (PSO): 0.06608597285067876
# Iteration: 5
# Best (PSO): 0.05981674208144799
# Iteration: 6
# Best (PSO): 0.05981674208144799
# Iteration: 7
# Best (PSO): 0.05981674208144799
# Iteration: 8
# Best (PSO): 0.05981674208144799
# Iteration: 9
# Best (PSO): 0.05981674208144799
# Iteration: 10
# Best (PSO): 0.05981674208144799
# Iteration: 11
# Best (PSO): 0.05981674208144799
# Iteration: 12
# Best (PSO): 0.05981674208144799
# Iteration: 13
# Best (PSO): 0.05981674208144799
# Iteration: 14
# Best (PSO): 0.05981674208144799
# Iteration: 15
# Best (PSO): 0.05981674208144799
# Iteration: 16
# Best (PSO): 0.05981674208144799
# Iteration: 17
# Best (PSO): 0.05981674208144799
# Iteration: 18
# Best (PSO): 0.05981674208144799
# Iteration: 19
# Best (PSO): 0.05981674208144799
# Iteration: 20
# Best (PSO): 0.05981674208144799
# SF [ 2  5  6  9 11]
# Accuracy: 94.34640522875817
# Feature Size: 5
# --------------------------------------------------
# Run  10
# -----------------------------------
# 0.012352782067388546
# Iteration: 1
# Best (PSO): 0.2966040723981901
# Iteration: 2
# Best (PSO): 0.29441855203619915
# Iteration: 3
# Best (PSO): 0.2928800904977376
# Iteration: 4
# Best (PSO): 0.2928800904977376
# Iteration: 5
# Best (PSO): 0.2928800904977376
# Iteration: 6
# Best (PSO): 0.2928800904977376
# Iteration: 7
# Best (PSO): 0.2928800904977376
# Iteration: 8
# Best (PSO): 0.2928800904977376
# Iteration: 9
# Best (PSO): 0.2928800904977376
# Iteration: 10
# Best (PSO): 0.2928800904977376
# Iteration: 11
# Best (PSO): 0.2928800904977376
# Iteration: 12
# Best (PSO): 0.2928800904977376
# Iteration: 13
# Best (PSO): 0.2928800904977376
# Iteration: 14
# Best (PSO): 0.2928800904977376
# Iteration: 15
# Best (PSO): 0.2928800904977376
# Iteration: 16
# Best (PSO): 0.2928800904977376
# Iteration: 17
# Best (PSO): 0.2928800904977376
# Iteration: 18
# Best (PSO): 0.2928800904977376
# Iteration: 19
# Best (PSO): 0.2928800904977376
# Iteration: 20
# Best (PSO): 0.2928800904977376
# SF [ 3  4  7  8  9 12]
# Accuracy: 70.88235294117646
# Feature Size: 6
# --------------------------------------------------
# Run  11
# -----------------------------------
# 0.8948444516342232
# Iteration: 1
# Best (PSO): 0.09953167420814482
# Iteration: 2
# Best (PSO): 0.09953167420814482
# Iteration: 3
# Best (PSO): 0.07785520361990952
# Iteration: 4
# Best (PSO): 0.06830769230769233
# Iteration: 5
# Best (PSO): 0.04234615384615387
# Iteration: 6
# Best (PSO): 0.04234615384615387
# Iteration: 7
# Best (PSO): 0.04234615384615387
# Iteration: 8
# Best (PSO): 0.04234615384615387
# Iteration: 9
# Best (PSO): 0.04234615384615387
# Iteration: 10
# Best (PSO): 0.04234615384615387
# Iteration: 11
# Best (PSO): 0.04234615384615387
# Iteration: 12
# Best (PSO): 0.04234615384615387
# Iteration: 13
# Best (PSO): 0.04234615384615387
# Iteration: 14
# Best (PSO): 0.04234615384615387
# Iteration: 15
# Best (PSO): 0.04234615384615387
# Iteration: 16
# Best (PSO): 0.04234615384615387
# Iteration: 17
# Best (PSO): 0.04234615384615387
# Iteration: 18
# Best (PSO): 0.04234615384615387
# Iteration: 19
# Best (PSO): 0.04234615384615387
# Iteration: 20
# Best (PSO): 0.04234615384615387
# SF [ 0  2  6  7 10]
# Accuracy: 96.1111111111111
# Feature Size: 5
# --------------------------------------------------
# Run  12
# -----------------------------------
# 0.3133685431094977
# Iteration: 1
# Best (PSO): 0.09281674208144798
# Iteration: 2
# Best (PSO): 0.07599321266968327
# Iteration: 3
# Best (PSO): 0.07599321266968327
# Iteration: 4
# Best (PSO): 0.07599321266968327
# Iteration: 5
# Best (PSO): 0.07599321266968327
# Iteration: 6
# Best (PSO): 0.07554751131221722
# Iteration: 7
# Best (PSO): 0.05840045248868781
# Iteration: 8
# Best (PSO): 0.05399321266968328
# Iteration: 9
# Best (PSO): 0.05399321266968328
# Iteration: 10
# Best (PSO): 0.04816968325791858
# Iteration: 11
# Best (PSO): 0.04816968325791858
# Iteration: 12
# Best (PSO): 0.04740045248868781
# Iteration: 13
# Best (PSO): 0.04740045248868781
# Iteration: 14
# Best (PSO): 0.04740045248868781
# Iteration: 15
# Best (PSO): 0.04740045248868781
# Iteration: 16
# Best (PSO): 0.04740045248868781
# Iteration: 17
# Best (PSO): 0.04740045248868781
# Iteration: 18
# Best (PSO): 0.04740045248868781
# Iteration: 19
# Best (PSO): 0.04740045248868781
# Iteration: 20
# Best (PSO): 0.04740045248868781
# SF [0 6 8 9]
# Accuracy: 95.52287581699348
# Feature Size: 4
# --------------------------------------------------
# Run  13
# -----------------------------------
# 0.06344296297022622
# Iteration: 1
# Best (PSO): 0.14219457013574666
# Iteration: 2
# Best (PSO): 0.14219457013574666
# Iteration: 3
# Best (PSO): 0.08577828054298643
# Iteration: 4
# Best (PSO): 0.08577828054298643
# Iteration: 5
# Best (PSO): 0.08577828054298643
# Iteration: 6
# Best (PSO): 0.08577828054298643
# Iteration: 7
# Best (PSO): 0.08577828054298643
# Iteration: 8
# Best (PSO): 0.08577828054298643
# Iteration: 9
# Best (PSO): 0.08577828054298643
# Iteration: 10
# Best (PSO): 0.08577828054298643
# Iteration: 11
# Best (PSO): 0.08577828054298643
# Iteration: 12
# Best (PSO): 0.08577828054298643
# Iteration: 13
# Best (PSO): 0.08577828054298643
# Iteration: 14
# Best (PSO): 0.08577828054298643
# Iteration: 15
# Best (PSO): 0.08577828054298643
# Iteration: 16
# Best (PSO): 0.08577828054298643
# Iteration: 17
# Best (PSO): 0.08577828054298643
# Iteration: 18
# Best (PSO): 0.08577828054298643
# Iteration: 19
# Best (PSO): 0.08577828054298643
# Iteration: 20
# Best (PSO): 0.08577828054298643
# SF [ 5  9 10]
# Accuracy: 91.56862745098039
# Feature Size: 3
# --------------------------------------------------
# Run  14
# -----------------------------------
# 0.7726403800703937
# Iteration: 1
# Best (PSO): 0.15772398190045253
# Iteration: 2
# Best (PSO): 0.15772398190045253
# Iteration: 3
# Best (PSO): 0.09613122171945702
# Iteration: 4
# Best (PSO): 0.0807239819004525
# Iteration: 5
# Best (PSO): 0.0807239819004525
# Iteration: 6
# Best (PSO): 0.0807239819004525
# Iteration: 7
# Best (PSO): 0.0807239819004525
# Iteration: 8
# Best (PSO): 0.06511538461538464
# Iteration: 9
# Best (PSO): 0.06466968325791858
# Iteration: 10
# Best (PSO): 0.06466968325791858
# Iteration: 11
# Best (PSO): 0.06466968325791858
# Iteration: 12
# Best (PSO): 0.06466968325791858
# Iteration: 13
# Best (PSO): 0.06466968325791858
# Iteration: 14
# Best (PSO): 0.06466968325791858
# Iteration: 15
# Best (PSO): 0.06466968325791858
# Iteration: 16
# Best (PSO): 0.06466968325791858
# Iteration: 17
# Best (PSO): 0.06466968325791858
# Iteration: 18
# Best (PSO): 0.06466968325791858
# Iteration: 19
# Best (PSO): 0.06466968325791858
# Iteration: 20
# Best (PSO): 0.06466968325791858
# SF [0 1 3 6 9]
# Accuracy: 93.85620915032679
# Feature Size: 5
# --------------------------------------------------
# Run  15
# -----------------------------------
# 0.31579676283877367
# Iteration: 1
# Best (PSO): 0.17167873303167422
# Iteration: 2
# Best (PSO): 0.08193891402714935
# Iteration: 3
# Best (PSO): 0.07170814479638012
# Iteration: 4
# Best (PSO): 0.0603846153846154
# Iteration: 5
# Best (PSO): 0.04311538461538463
# Iteration: 6
# Best (PSO): 0.04311538461538463
# Iteration: 7
# Best (PSO): 0.04311538461538463
# Iteration: 8
# Best (PSO): 0.04311538461538463
# Iteration: 9
# Best (PSO): 0.04311538461538463
# Iteration: 10
# Best (PSO): 0.04311538461538463
# Iteration: 11
# Best (PSO): 0.04311538461538463
# Iteration: 12
# Best (PSO): 0.04311538461538463
# Iteration: 13
# Best (PSO): 0.04311538461538463
# Iteration: 14
# Best (PSO): 0.04311538461538463
# Iteration: 15
# Best (PSO): 0.04311538461538463
# Iteration: 16
# Best (PSO): 0.04311538461538463
# Iteration: 17
# Best (PSO): 0.04311538461538463
# Iteration: 18
# Best (PSO): 0.04311538461538463
# Iteration: 19
# Best (PSO): 0.04311538461538463
# Iteration: 20
# Best (PSO): 0.04311538461538463
# SF [ 0  2  5  6  8 10]
# Accuracy: 96.1111111111111
# Feature Size: 6
# --------------------------------------------------
# Run  16
# -----------------------------------
# 0.985247570883711
# Iteration: 1
# Best (PSO): 0.07049321266968328
# Iteration: 2
# Best (PSO): 0.06499321266968329
# Iteration: 3
# Best (PSO): 0.05476244343891405
# Iteration: 4
# Best (PSO): 0.05476244343891405
# Iteration: 5
# Best (PSO): 0.05476244343891405
# Iteration: 6
# Best (PSO): 0.05476244343891405
# Iteration: 7
# Best (PSO): 0.05476244343891405
# Iteration: 8
# Best (PSO): 0.05476244343891405
# Iteration: 9
# Best (PSO): 0.05476244343891405
# Iteration: 10
# Best (PSO): 0.05476244343891405
# Iteration: 11
# Best (PSO): 0.05476244343891405
# Iteration: 12
# Best (PSO): 0.05476244343891405
# Iteration: 13
# Best (PSO): 0.05476244343891405
# Iteration: 14
# Best (PSO): 0.05476244343891405
# Iteration: 15
# Best (PSO): 0.05476244343891405
# Iteration: 16
# Best (PSO): 0.05476244343891405
# Iteration: 17
# Best (PSO): 0.05476244343891405
# Iteration: 18
# Best (PSO): 0.05476244343891405
# Iteration: 19
# Best (PSO): 0.05476244343891405
# Iteration: 20
# Best (PSO): 0.05476244343891405
# SF [0 1 5 6 7 9]
# Accuracy: 94.93464052287581
# Feature Size: 6
# --------------------------------------------------
# Run  17
# -----------------------------------
# 0.6122177116340927
# Iteration: 1
# Best (PSO): 0.17551809954751132
# Iteration: 2
# Best (PSO): 0.1177714932126697
# Iteration: 3
# Best (PSO): 0.06653167420814482
# Iteration: 4
# Best (PSO): 0.05366968325791857
# Iteration: 5
# Best (PSO): 0.05366968325791857
# Iteration: 6
# Best (PSO): 0.05366968325791857
# Iteration: 7
# Best (PSO): 0.05366968325791857
# Iteration: 8
# Best (PSO): 0.05366968325791857
# Iteration: 9
# Best (PSO): 0.05366968325791857
# Iteration: 10
# Best (PSO): 0.05366968325791857
# Iteration: 11
# Best (PSO): 0.05366968325791857
# Iteration: 12
# Best (PSO): 0.05366968325791857
# Iteration: 13
# Best (PSO): 0.05366968325791857
# Iteration: 14
# Best (PSO): 0.05366968325791857
# Iteration: 15
# Best (PSO): 0.05366968325791857
# Iteration: 16
# Best (PSO): 0.05366968325791857
# Iteration: 17
# Best (PSO): 0.05366968325791857
# Iteration: 18
# Best (PSO): 0.05366968325791857
# Iteration: 19
# Best (PSO): 0.05366968325791857
# Iteration: 20
# Best (PSO): 0.05366968325791857
# SF [1 2 5 6 9]
# Accuracy: 94.9673202614379
# Feature Size: 5
# --------------------------------------------------
# Run  18
# -----------------------------------
# 0.8390447238040811
# Iteration: 1
# Best (PSO): 0.1936787330316742
# Iteration: 2
# Best (PSO): 0.17794796380090497
# Iteration: 3
# Best (PSO): 0.17794796380090497
# Iteration: 4
# Best (PSO): 0.17794796380090497
# Iteration: 5
# Best (PSO): 0.16739366515837106
# Iteration: 6
# Best (PSO): 0.16739366515837106
# Iteration: 7
# Best (PSO): 0.14462443438914027
# Iteration: 8
# Best (PSO): 0.14462443438914027
# Iteration: 9
# Best (PSO): 0.1438552036199095
# Iteration: 10
# Best (PSO): 0.14308597285067876
# Iteration: 11
# Best (PSO): 0.14308597285067876
# Iteration: 12
# Best (PSO): 0.14308597285067876
# Iteration: 13
# Best (PSO): 0.14308597285067876
# Iteration: 14
# Best (PSO): 0.14308597285067876
# Iteration: 15
# Best (PSO): 0.14308597285067876
# Iteration: 16
# Best (PSO): 0.14308597285067876
# Iteration: 17
# Best (PSO): 0.14308597285067876
# Iteration: 18
# Best (PSO): 0.14308597285067876
# Iteration: 19
# Best (PSO): 0.14308597285067876
# Iteration: 20
# Best (PSO): 0.14308597285067876
# SF [ 0  4  6  8  9 11]
# Accuracy: 86.01307189542483
# Feature Size: 6
# --------------------------------------------------
# Run  19
# -----------------------------------
# 0.9380006877954246
# Iteration: 1
# Best (PSO): 0.14878733031674213
# Iteration: 2
# Best (PSO): 0.08367873303167424
# Iteration: 3
# Best (PSO): 0.05015384615384619
# Iteration: 4
# Best (PSO): 0.05015384615384619
# Iteration: 5
# Best (PSO): 0.049384615384615416
# Iteration: 6
# Best (PSO): 0.049384615384615416
# Iteration: 7
# Best (PSO): 0.049384615384615416
# Iteration: 8
# Best (PSO): 0.049384615384615416
# Iteration: 9
# Best (PSO): 0.049384615384615416
# Iteration: 10
# Best (PSO): 0.049384615384615416
# Iteration: 11
# Best (PSO): 0.049384615384615416
# Iteration: 12
# Best (PSO): 0.049384615384615416
# Iteration: 13
# Best (PSO): 0.049384615384615416
# Iteration: 14
# Best (PSO): 0.049384615384615416
# Iteration: 15
# Best (PSO): 0.049384615384615416
# Iteration: 16
# Best (PSO): 0.049384615384615416
# Iteration: 17
# Best (PSO): 0.049384615384615416
# Iteration: 18
# Best (PSO): 0.049384615384615416
# Iteration: 19
# Best (PSO): 0.049384615384615416
# Iteration: 20
# Best (PSO): 0.049384615384615416
# SF [ 0  3  6  8  9 10 11]
# Accuracy: 95.55555555555554
# Feature Size: 7
# --------------------------------------------------
# Run  20
# -----------------------------------
# 0.75023120454533
# Iteration: 1
# Best (PSO): 0.06620814479638011
# Iteration: 2
# Best (PSO): 0.06620814479638011
# Iteration: 3
# Best (PSO): 0.06620814479638011
# Iteration: 4
# Best (PSO): 0.06620814479638011
# Iteration: 5
# Best (PSO): 0.06620814479638011
# Iteration: 6
# Best (PSO): 0.06620814479638011
# Iteration: 7
# Best (PSO): 0.06620814479638011
# Iteration: 8
# Best (PSO): 0.06620814479638011
# Iteration: 9
# Best (PSO): 0.06620814479638011
# Iteration: 10
# Best (PSO): 0.06620814479638011
# Iteration: 11
# Best (PSO): 0.06620814479638011
# Iteration: 12
# Best (PSO): 0.06620814479638011
# Iteration: 13
# Best (PSO): 0.06620814479638011
# Iteration: 14
# Best (PSO): 0.06620814479638011
# Iteration: 15
# Best (PSO): 0.06620814479638011
# Iteration: 16
# Best (PSO): 0.06620814479638011
# Iteration: 17
# Best (PSO): 0.06620814479638011
# Iteration: 18
# Best (PSO): 0.06620814479638011
# Iteration: 19
# Best (PSO): 0.06466968325791857
# Iteration: 20
# Best (PSO): 0.06466968325791857
# SF [ 0  5  6 10 11]
# Accuracy: 93.85620915032679
# Feature Size: 5
# --------------------------------------------------

# %%
print("Average Accuracy: ", np.mean(acc_arr))
print("Average number of features selected: ", np.mean(feature_size_arr))
# Out:
# Average Accuracy:  92.13235294117646
# Average number of features selected:  5.35
